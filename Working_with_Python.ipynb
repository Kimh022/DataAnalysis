# %%
import pandas as pd

# %%
trees = pd.read_csv("trees.csv")

# %%
type(trees)
# Out:
# pandas.core.frame.DataFrame

# %%
trees.head()
# Out:
#    Girth  Height  Volume Zone
# 0    8.3      70    10.3    B
# 1    8.6      65    10.3    A
# 2    8.8      63    10.2    A
# 3   10.5      72    16.4    A
# 4   10.7      81    18.8    B

# %%
trees.head(10)
# Out:
#    Girth  Height  Volume Zone
# 0    8.3      70    10.3    B
# 1    8.6      65    10.3    A
# 2    8.8      63    10.2    A
# 3   10.5      72    16.4    A
# 4   10.7      81    18.8    B
# 5   10.8      83    19.7    A
# 6   11.0      66    15.6    A
# 7   11.0      75    18.2    A
# 8   11.1      80    22.6    A
# 9   11.2      75    19.9    B

# %%
trees.tail()
# Out:
#     Girth  Height  Volume Zone
# 26   17.5      82    55.7    A
# 27   17.9      80    58.3    A
# 28   18.0      80    51.5    B
# 29   18.0      80    51.0    B
# 30   20.6      87    77.0    B

# %%
trees.tail(10
           )
# Out:
#     Girth  Height  Volume Zone
# 21   14.2      80    31.7    A
# 22   14.5      74    36.3    A
# 23   16.0      72    38.3    A
# 24   16.3      77    42.6    A
# 25   17.3      81    55.4    A
# 26   17.5      82    55.7    A
# 27   17.9      80    58.3    A
# 28   18.0      80    51.5    B
# 29   18.0      80    51.0    B
# 30   20.6      87    77.0    B

# %%
trees.Girth.head()
# Out:
# 0     8.3
# 1     8.6
# 2     8.8
# 3    10.5
# 4    10.7
# Name: Girth, dtype: float64

# %%
trees['Girth'].head()
# Out:
# 0     8.3
# 1     8.6
# 2     8.8
# 3    10.5
# 4    10.7
# Name: Girth, dtype: float64

# %%
trees['Volume'].tail()
# Out:
# 26    55.7
# 27    58.3
# 28    51.5
# 29    51.0
# 30    77.0
# Name: Volume, dtype: float64

# %%
len(trees)
# Out:
# 31

# %%
trees.count()
# Out:
# Girth     31
# Height    31
# Volume    31
# Zone      31
# dtype: int64

# %%
trees.describe()
# Out:
#            Girth     Height     Volume
# count  31.000000  31.000000  31.000000
# mean   13.248387  76.000000  30.170968
# std     3.138139   6.371813  16.437846
# min     8.300000  63.000000  10.200000
# 25%    11.050000  72.000000  19.400000
# 50%    12.900000  76.000000  24.200000
# 75%    15.250000  80.000000  37.300000
# max    20.600000  87.000000  77.000000

# %%
trees['Girth'].mean()
# Out:
# 13.248387096774195

# %%
trees['Girth'].std()
# Out:
# 3.1381386168387504

# %%
trees['Volume'].mean()
# Out:
# 30.17096774193548

# %%
trees['Volume'].std()
# Out:
# 16.43784644346469

# %%
trees['Height'].mean()
# Out:
# 76.0

# %%
trees['Height'].std()
# Out:
# 6.371812928829597

# %%
zoneA = trees.loc[trees['Zone'] == 'A']
zoneB = trees.loc[trees['Zone'] == 'A']

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(trees['Girth'],bins =30)
plt.xlabel('Girth')
# Out:
# Text(0.5, 0, 'Girth')

# %%
plt.plot(trees['Girth'], trees['Volume'], 'o', color = 'green')
plt.xlabel('Girth')
plt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
plt.plot(trees['Height'],trees['Volume'], 'o', color ='blue')
plt.xlabel('Height')
plt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')
